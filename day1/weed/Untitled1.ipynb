# %% [markdown]
# ## With love from podicus!

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.17.1'

# %%
# !pip freeze
# Out:
# abstract-rendering==0.5.1
# alabaster==0.7.6
# anaconda-client==1.2.1
# argcomplete==1.0.0
# astropy==1.0.6
# Babel==2.1.1
# beautifulsoup4==4.4.1
# bitarray==0.8.1
# blaze==0.8.3
# bokeh==0.10.0
# boto==2.38.0
# Bottleneck==1.0.0
# cffi==1.2.1
# clyent==1.2.0
# colorama==0.3.3
# conda==3.18.9
# conda-build==1.18.2
# conda-env==2.4.5
# configobj==5.0.6
# cryptography==0.9.3
# cycler==0.9.0
# Cython==0.23.4
# cytoolz==0.7.4
# datashape==0.4.7
# decorator==4.0.4
# docutils==0.12
# dynd==9b63882
# fastcache==1.0.2
# Flask==0.10.1
# greenlet==0.4.9
# h5py==2.5.0
# idna==2.0
# ipykernel==4.1.1
# ipython==4.0.1
# ipython-genutils==0.1.0
# ipywidgets==4.1.0
# itsdangerous==0.24
# jdcal==1.0
# jedi==0.9.0
# Jinja2==2.8
# jsonschema==2.4.0
# jupyter==1.0.0
# jupyter-client==4.1.1
# jupyter-console==4.0.3
# jupyter-core==4.0.6
# llvmlite==0.8.0
# lxml==3.4.4
# MarkupSafe==0.23
# matplotlib==1.5.0
# mistune==0.7.1
# multipledispatch==0.4.8
# nbconvert==4.0.0
# nbformat==4.0.1
# networkx==1.10
# ...

# %%
# !ls
# Out:
# 0-Intro.ipynb	 5-Insight.ipynb  LICENSE		  Untitled1.ipynb
# 1-Acquire.ipynb  AnalysisR.ipynb  map.html		  Untitled.ipynb
# 2-Refine.ipynb	 data		  README.md
# 3-Explore.ipynb  data.json	  requirements_linux.txt
# 4-Model.ipynb	 img		  requirements.txt

# %%
## read the data.
weed = pd.read_csv("data/Weed_Price.csv", index_col=0)

# %%
weed.head
# Out:
# <bound method NDFrame.head of                        HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# State
# Alabama               339.06    1042  198.64    933  149.49    123  2014-01-01
# Alaska                288.75     252  260.60    297  388.58     26  2014-01-01
# Arizona               303.31    1941  209.35   1625  189.45    222  2014-01-01
# Arkansas              361.85     576  185.62    544  125.87    112  2014-01-01
# California            248.78   12096  193.56  12812  192.92    778  2014-01-01
# Colorado              236.31    2161  195.29   1728  213.50    128  2014-01-01
# Connecticut           347.90    1294  273.97   1316  257.36     91  2014-01-01
# Delaware              373.18     347  226.25    273  199.88     34  2014-01-01
# District of Columbia  352.26     433  295.67    349  213.72     39  2014-01-01
# Florida               306.43    6506  220.03   5237  158.26    514  2014-01-01
# ...

# %%
weed.tail
# Out:
# <bound method NDFrame.tail of                       State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN  \
# 0                   Alabama  339.06    1042  198.64    933  149.49    123
# 1                    Alaska  288.75     252  260.60    297  388.58     26
# 2                   Arizona  303.31    1941  209.35   1625  189.45    222
# 3                  Arkansas  361.85     576  185.62    544  125.87    112
# 4                California  248.78   12096  193.56  12812  192.92    778
# 5                  Colorado  236.31    2161  195.29   1728  213.50    128
# 6               Connecticut  347.90    1294  273.97   1316  257.36     91
# 7                  Delaware  373.18     347  226.25    273  199.88     34
# 8      District of Columbia  352.26     433  295.67    349  213.72     39
# 9                   Florida  306.43    6506  220.03   5237  158.26    514
# 10                  Georgia  332.21    3099  213.52   2269  153.45    229
# ...

# %%
weed.columns
# Out:
# Index(['HighQ', 'HighQN', 'MedQ', 'MedQN', 'LowQ', 'LowQN', 'date'], dtype='object')

# %%
weed.dtypes
# Out:
# HighQ     float64
# HighQN      int64
# MedQ      float64
# MedQN       int64
# LowQ      float64
# LowQN       int64
# date       object
# dtype: object

# %%
weed.tail()
# Out:
#                 HighQ  HighQN    MedQ  MedQN  LowQ  LowQN        date
# State
# Virginia       364.98    3513  293.12   3079   NaN    284  2014-12-31
# Washington     233.05    3337  189.92   3562   NaN    160  2014-12-31
# West Virginia  359.35     551  224.03    545   NaN     60  2014-12-31
# Wisconsin      350.52    2244  272.71   2221   NaN    167  2014-12-31
# Wyoming        322.27     131  351.86    197   NaN     12  2014-12-31

# %%
weed.head()
# Out:
#              HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# State
# Alabama     339.06    1042  198.64    933  149.49    123  2014-01-01
# Alaska      288.75     252  260.60    297  388.58     26  2014-01-01
# Arizona     303.31    1941  209.35   1625  189.45    222  2014-01-01
# Arkansas    361.85     576  185.62    544  125.87    112  2014-01-01
# California  248.78   12096  193.56  12812  192.92    778  2014-01-01

# %%
weed.dtypes
# Out:
# HighQ     float64
# HighQN      int64
# MedQ      float64
# MedQN       int64
# LowQ      float64
# LowQN       int64
# date       object
# dtype: object

# %%
## we have a date issue above

# %%
weed = pd.read_csv("data/Weed_Price.csv", parse_dates=[-1])
## getting an error here, correct it later

# %%
weed.rename(columns={'HighQN': 'PeoplBoughtHighQuality'})
# Out:
#                        HighQ  PeoplBoughtHighQuality    MedQ  MedQN    LowQ  \
# State
# Alabama               339.06                    1042  198.64    933  149.49
# Alaska                288.75                     252  260.60    297  388.58
# Arizona               303.31                    1941  209.35   1625  189.45
# Arkansas              361.85                     576  185.62    544  125.87
# California            248.78                   12096  193.56  12812  192.92
# Colorado              236.31                    2161  195.29   1728  213.50
# Connecticut           347.90                    1294  273.97   1316  257.36
# Delaware              373.18                     347  226.25    273  199.88
# District of Columbia  352.26                     433  295.67    349  213.72
# Florida               306.43                    6506  220.03   5237  158.26
# Georgia               332.21                    3099  213.52   2269  153.45
# ...

# %%
weed.head()
# Out:
#              HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# State
# Alabama     339.06    1042  198.64    933  149.49    123  2014-01-01
# Alaska      288.75     252  260.60    297  388.58     26  2014-01-01
# Arizona     303.31    1941  209.35   1625  189.45    222  2014-01-01
# Arkansas    361.85     576  185.62    544  125.87    112  2014-01-01
# California  248.78   12096  193.56  12812  192.92    778  2014-01-01

# %%
## sub-select rows

# %%
weed[15:20]
# Out:
#             HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# State
# Iowa       371.70     697  292.34    649  252.24    103  2014-01-01
# Kansas     353.51     838  260.97    628  124.27    109  2014-01-01
# Kentucky   337.33    1013  183.17    986  120.31    132  2014-01-01
# Louisiana  377.71    1071  243.26    864  153.73    224  2014-01-01
# Maine      321.10     450  259.18    425  214.80     52  2014-01-01

# %%
weed[['State', 'HighQ']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-9ba1db4c3ef8> in <module>()
# ----> 1 weed[['State', 'HighQ']]
#
# /home/tasdik/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /home/tasdik/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# ...

# %%
weed.dtypes
# Out:
# State             object
# HighQ            float64
# HighQN             int64
# MedQ             float64
# MedQN              int64
# LowQ             float64
# LowQN              int64
# date      datetime64[ns]
# dtype: object

# %%
weed.loc[15:20 ,['State, 'date']]
# Out:
#   File "<ipython-input-37-68d5ead1105b>", line 1
#     weed.loc[15:20 ,['State, 'date']]
#                                  ^
# SyntaxError: invalid syntax

# %%
weed.State
# Out:
# 0                     Alabama
# 1                      Alaska
# 2                     Arizona
# 3                    Arkansas
# 4                  California
# 5                    Colorado
# 6                 Connecticut
# 7                    Delaware
# 8        District of Columbia
# 9                     Florida
# 10                    Georgia
# 11                     Hawaii
# 12                      Idaho
# 13                   Illinois
# 14                    Indiana
# 15                       Iowa
# 16                     Kansas
# 17                   Kentucky
# 18                  Louisiana
# 19                      Maine
# 20                    Montana
# 21                   Nebraska
# 22                     Nevada
# 23              New Hampshire
# 24                 New Jersey
# 25                 New Mexico
# 26                   New York
# 27             North Carolina
# 28               North Dakota
# 29                       Ohio
#                  ...
# ...

# %%
## now get to know only the unique ones

# %%
weed.State.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Pennsylvania', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming'], dtype=object)

# %%
weed.loc[10:15]
# Out:
#        State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 10   Georgia  332.21    3099  213.52   2269  153.45    229 2014-01-01
# 11    Hawaii  310.96     328  270.38    350  160.46     25 2014-01-01
# 12     Idaho  276.05     315  254.96    445  132.61     20 2014-01-01
# 13  Illinois  359.74    4008  287.23   3644  181.25    329 2014-01-01
# 14   Indiana  336.80    1665  206.24   1446  154.05    248 2014-01-01
# 15      Iowa  371.70     697  292.34    649  252.24    103 2014-01-01

# %%
weed_new = weed.copy()

# %%
weed_new.shape
# Out:
# (22899, 8)

# %%
weed_new[10:15]
# Out:
#        State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 10   Georgia  332.21    3099  213.52   2269  153.45    229 2014-01-01
# 11    Hawaii  310.96     328  270.38    350  160.46     25 2014-01-01
# 12     Idaho  276.05     315  254.96    445  132.61     20 2014-01-01
# 13  Illinois  359.74    4008  287.23   3644  181.25    329 2014-01-01
# 14   Indiana  336.80    1665  206.24   1446  154.05    248 2014-01-01

# %%
weed_new.loc[10:15]
# Out:
#        State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 10   Georgia  332.21    3099  213.52   2269  153.45    229 2014-01-01
# 11    Hawaii  310.96     328  270.38    350  160.46     25 2014-01-01
# 12     Idaho  276.05     315  254.96    445  132.61     20 2014-01-01
# 13  Illinois  359.74    4008  287.23   3644  181.25    329 2014-01-01
# 14   Indiana  336.80    1665  206.24   1446  154.05    248 2014-01-01
# 15      Iowa  371.70     697  292.34    649  252.24    103 2014-01-01

# %%
weed_new.count()
# Out:
# State     22899
# HighQ     22899
# HighQN    22899
# MedQ      22899
# MedQN     22899
# LowQ      12342
# LowQN     22899
# date      22899
# dtype: int64

# %%
weed_new.LowQ
# Out:
# 0        149.49
# 1        388.58
# 2        189.45
# 3        125.87
# 4        192.92
# 5        213.50
# 6        257.36
# 7        199.88
# 8        213.72
# 9        158.26
# 10       153.45
# 11       160.46
# 12       132.61
# 13       181.25
# 14       154.05
# 15       252.24
# 16       124.27
# 17       120.31
# 18       153.73
# 19       214.80
# 20       734.65
# 21       142.99
# 22       231.08
# 23       561.05
# 24       225.62
# 25        63.70
# 26       190.38
# 27       152.09
# 28       269.55
# 29       168.87
#           ...
# 22869       NaN
# 22870       NaN
# 22871       NaN
# 22872       NaN
# 22873       NaN
# 22874       NaN
# 22875       NaN
# 22876       NaN
# 22877       NaN
# 22878       NaN
# 22879       NaN
# 22880       NaN
# 22881       NaN
# 22882       NaN
# 22883       NaN
# 22884       NaN
# 22885       NaN
# 22886       NaN
# 22887       NaN
# 22888       NaN
# 22889       NaN
# 22890       NaN
# 22891       NaN
# 22892       NaN
# ...

# %%
weed_new[weed_new.LowQ.isnull()]
# Out:
#                       State   HighQ  HighQN    MedQ  MedQN  LowQ  LowQN  \
# 51                  Alabama  337.54    1539  208.24   1463   NaN    182
# 52                   Alaska  303.02     350  270.45    475   NaN     37
# 53                  Arizona  298.51    2638  209.43   2426   NaN    306
# 54                 Arkansas  341.68     846  207.20    836   NaN    145
# 55               California  243.96   16512  189.35  19151   NaN   1096
# 56                 Colorado  243.72    3148  195.11   2877   NaN    178
# 57              Connecticut  337.26    1835  267.99   2069   NaN    126
# 58                 Delaware  364.19     490  234.72    431   NaN     41
# 59     District of Columbia  348.66     657  281.93    578   NaN     49
# 60                  Florida  300.88    9369  217.05   8166   NaN    695
# 61                  Georgia  324.30    4422  217.17   3467   NaN    303
# 62                   Hawaii  307.64     452  263.45    522   NaN     30
# ...

# %%
## how to replace the missing data here! Like the date's missing here.

# %%
weed.sort(columns=["State, "date")
# Out:
#   File "<ipython-input-57-26b9d50eb171>", line 1
#     weed.sort(columns=["State, "date")
#                                    ^
# SyntaxError: invalid syntax

# %%
weed_new.State.value_counts().unique()
# Out:
# array([449])

# %%
weed_ca = weed_new[weed_new.State=="California"]

# %%
weed_ca
# Out:
#             State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 4      California  248.78   12096  193.56  12812  192.92    778 2014-01-01
# 55     California  243.96   16512  189.35  19151     NaN   1096 2015-01-01
# 106    California  248.20   12571  192.80  13406  191.94    804 2014-02-01
# 157    California  243.30   16904  188.95  19764     NaN   1123 2015-02-01
# 208    California  247.60   12988  192.97  13906  191.40    839 2014-03-01
# 259    California  246.76   13396  192.91  14527  191.98    863 2014-04-01
# 310    California  246.04   13787  191.89  15047  191.40    891 2014-05-01
# 361    California  245.71   14178  192.27  15588  190.06    930 2014-06-01
# 412    California  241.92   18468  187.87  22012     NaN   1231 2015-06-01
# 463    California  245.39   14539  191.94  16092  188.57    949 2014-07-01
# 514    California  245.36   14948  191.58  16665  188.03    976 2014-08-01
# ...

# %%
print(weed_ca.date.min(), weed_ca.date.max())
# Out:
# 2013-12-27 00:00:00 2015-06-11 00:00:00

# %%
weed_ca.date.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 4       2014-01-01
# 55      2015-01-01
# 106     2014-02-01
# 157     2015-02-01
# 208     2014-03-01
# 259     2014-04-01
# 310     2014-05-01
# 361     2014-06-01
# 412     2015-06-01
# 463     2014-07-01
# 514     2014-08-01
# 565     2014-09-01
# 616     2014-10-01
# 667     2014-11-01
# 718     2014-12-01
# 769     2014-01-02
# 820     2015-01-02
# 871     2014-02-02
# 922     2015-02-02
# 973     2014-03-02
# 1024    2014-04-02
# 1075    2014-05-02
# 1126    2014-06-02
# 1177    2015-06-02
# 1228    2014-07-02
# 1279    2014-09-02
# 1330    2014-10-02
# 1381    2014-11-02
# 1432    2014-12-02
# 1483    2014-01-03
#            ...
# 21373   2014-08-29
# 21424   2014-09-29
# 21475   2014-10-29
# 21526   2014-11-29
# 21577   2013-12-29
# 21628   2014-12-29
# 21679   2014-01-30
# 21730   2015-01-30
# 21781   2014-03-30
# 21832   2014-04-30
# 21883   2014-05-30
# 21934   2015-05-30
# 21985   2014-06-30
# 22036   2014-07-30
# ...
